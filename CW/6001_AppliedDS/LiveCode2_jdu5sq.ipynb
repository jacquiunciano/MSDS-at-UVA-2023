# %%
import numpy as np
import pandas as pd
import json
import requests

# %%
url = "http://www.thecocktaildb.com/api/json/v1/1/filter.php?c=Cocktail"
r = requests.get(url)
## checks if it's successful
r
# Out:
# <Response [200]>

# %%
## check to see the data itself
r.text
# Out:
# '{"drinks":[{"strDrink":"155 Belmont","strDrinkThumb":"https:\\/\\/www.thecocktaildb.com\\/images\\/media\\/drink\\/yqvvqs1475667388.jpg","idDrink":"15346"},{"strDrink":"57 Chevy with a White License Plate","strDrinkThumb":"https:\\/\\/www.thecocktaildb.com\\/images\\/media\\/drink\\/qyyvtu1468878544.jpg","idDrink":"14029"},{"strDrink":"747 Drink","strDrinkThumb":"https:\\/\\/www.thecocktaildb.com\\/images\\/media\\/drink\\/i9suxb1582474926.jpg","idDrink":"178318"},{"strDrink":"9 1\\/2 Weeks","strDrinkThumb":"https:\\/\\/www.thecocktaildb.com\\/images\\/media\\/drink\\/xvwusr1472669302.jpg","idDrink":"16108"},{"strDrink":"A Gilligan\'s Island","strDrinkThumb":"https:\\/\\/www.thecocktaildb.com\\/images\\/media\\/drink\\/wysqut1461867176.jpg","idDrink":"16943"},{"strDrink":"A True Amaretto Sour","strDrinkThumb":"https:\\/\\/www.thecocktaildb.com\\/images\\/media\\/drink\\/rptuxy1472669372.jpg","idDrink":"17005"},{"strDrink":"A.D.M. (After Dinner Mint)","strDrinkThumb":"https:\\/\\/www
# ...

# %%
## load without the s is from file
## also have dump or dumps
## we see the data in more organised fashion
json.loads(r.text)
# Out:
# {'drinks': [{'strDrink': '155 Belmont',
#    'strDrinkThumb': 'https://www.thecocktaildb.com/images/media/drink/yqvvqs1475667388.jpg',
#    'idDrink': '15346'},
#   {'strDrink': '57 Chevy with a White License Plate',
#    'strDrinkThumb': 'https://www.thecocktaildb.com/images/media/drink/qyyvtu1468878544.jpg',
#    'idDrink': '14029'},
#   {'strDrink': '747 Drink',
#    'strDrinkThumb': 'https://www.thecocktaildb.com/images/media/drink/i9suxb1582474926.jpg',
#    'idDrink': '178318'},
#   {'strDrink': '9 1/2 Weeks',
#    'strDrinkThumb': 'https://www.thecocktaildb.com/images/media/drink/xvwusr1472669302.jpg',
#    'idDrink': '16108'},
#   {'strDrink': "A Gilligan's Island",
#    'strDrinkThumb': 'https://www.thecocktaildb.com/images/media/drink/wysqut1461867176.jpg',
#    'idDrink': '16943'},
#   {'strDrink': 'A True Amaretto Sour',
#    'strDrinkThumb': 'https://www.thecocktaildb.com/images/media/drink/rptuxy1472669372.jpg',
#    'idDrink': '17005'},
# ...

# %%
drinks = json.loads(r.text)

# %%
drinks["drinks"][0]
# Out:
# {'strDrink': '155 Belmont',
#  'strDrinkThumb': 'https://www.thecocktaildb.com/images/media/drink/yqvvqs1475667388.jpg',
#  'idDrink': '15346'}

# %%
drinks["drinks"][0]["strDrink"]
# Out:
# '155 Belmont'

# %%
num = [1,2,3,4,5]

# %%
[np.sqrt(x**2-1) for x in num]
# Out:
# [0.0,
#  1.7320508075688772,
#  2.8284271247461903,
#  3.872983346207417,
#  4.898979485566356]

# %%
[d["strDrink"] for d in drinks["drinks"]]
# Out:
# ['155 Belmont',
#  '57 Chevy with a White License Plate',
#  '747 Drink',
#  '9 1/2 Weeks',
#  "A Gilligan's Island",
#  'A True Amaretto Sour',
#  'A.D.M. (After Dinner Mint)',
#  'A1',
#  'Abbey Martini',
#  'Absolut Summertime',
#  'Absolutely Fabulous',
#  'Absolutly Screwed Up',
#  'Ace',
#  'Adam & Eve',
#  'Addington',
#  'Addison',
#  'Addison Special',
#  'Adios Amigos Cocktail',
#  'Afterglow',
#  'Alice Cocktail',
#  'Amaretto fizz',
#  'Aperol Spritz',
#  'Apple Highball',
#  'Apple Karate',
#  'Applejack',
#  'Aquamarine',
#  'Arizona Stingers',
#  'Arizona Twister',
#  'Army special',
#  'Autumn Garibaldi',
#  'Aviation',
#  'Bahama Mama',
#  'Banana Cream Pi',
#  "Bee's Knees",
#  'Bijou',
#  'Blue Hurricane',
#  'Blueberry Mojito',
#  'Bombay Cassis',
#  'Bora Bora',
#  'Boulevardier',
#  'Bounty Hunter',
#  'Brigadier',
#  'Broadside',
#  'Brooklyn',
#  'Butterfly Effect',
#  "Captain Kidd's Punch",
#  'Cherry Electric Lemonade',
#  'Cocktail Horse’s Neck',
# ...

# %%
## second argument: it's a df now yay 
pd.json_normalize(drinks, record_path=["drinks"])
# Out:
#                                strDrink  \
# 0                           155 Belmont
# 1   57 Chevy with a White License Plate
# 2                             747 Drink
# 3                           9 1/2 Weeks
# 4                   A Gilligan's Island
# ..                                  ...
# 95                           Miami Vice
# 96                            Michelada
# 97                        Midnight Mint
# 98                               Mojito
# 99                         Mojito Extra
#
#                                         strDrinkThumb idDrink
# 0   https://www.thecocktaildb.com/images/media/dri...   15346
# 1   https://www.thecocktaildb.com/images/media/dri...   14029
# 2   https://www.thecocktaildb.com/images/media/dri...  178318
# 3   https://www.thecocktaildb.com/images/media/dri...   16108
# 4   https://www.thecocktaildb.com/images/media/dri...   16943
# ..                                                ...     ...
# ...

# %%
url2 = "https://en.wikipedia.org/w/api.php?action=query&list=search&srsearch=Virginia&format=json&srlimit=500"
r = requests.get(url2)
r
# Out:
# <Response [200]>

# %%
mj = json.loads(r.text)

# %%
## can find the record path using json hero
wiki = pd.json_normalize(mj, record_path=["query","search"])

# %%
wiki
# Out:
#      ns                                              title    pageid    size  \
# 0     0                                           Virginia     32432  299870
# 1     0                                      West Virginia     32905  183464
# 2     0                           Virginia Beach, Virginia     91239  141238
# 3     0                                     Virginia Woolf     32742  331505
# 4     0                                           Virgínia   1392216    2035
# ..   ..                                                ...       ...     ...
# 495   0                             Chesterfield, Virginia    137546    7859
# 496   0                           Mechanicsville, Virginia    137629   11820
# 497   0              President of the West Virginia Senate   9610864   26829
# 498   0  List of former primary state highways in Virgi...  43834000   46653
# 499   0  1984 United States presidential election in We...  41228984   51461
#
# ...

# %%
## don't do this bc you're gonna give away your API key!!!
## BADBADBADBADBADBADBADBADBADBADBADBADBADBADBADBADBADBAD
## DONT DO ITTTTTTTT
## I don't want to do the API thingy, so I'm going to follow the code instead
apikey = "somethingrandom"

# %%
url3 = "https://newsapi.org/v2/everything"
parameters = {"apikey":apikey,
             "q":"hasbulla"}
r = requests.get(url3, params=parameters)

# %%
r.text
# Out:
# '{"status":"error","code":"apiKeyInvalid","message":"Your API key is invalid or incorrect. Check your key, or go to https://newsapi.org to create a free API key."}'

# %%
rand = json.loads(r.text)

# %%
pd.json_normalize(rand, record_path=["articles"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\io\json\_normalize.py:399, in _json_normalize.<locals>._pull_field(js, spec, extract_record)
#     398     else:
# --> 399         result = result[spec]
#     400 except KeyError as e:
#
# KeyError: 'articles'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 pd.json_normalize(rand, record_path=["articles"])
#
# File ~\anaconda3\lib\site-packages\pandas\io\json\_normalize.py:518, in _json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     515                 meta_vals[key].append(meta_val)
#     516             records.extend(recs)
# --> 518 _recursive_extract(data, record_path, {}, level=0)
# ...
