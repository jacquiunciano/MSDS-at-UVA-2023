# %% [markdown]
# # Lab Assignment 8: Data Management Using `pandas`, Part 1
# ## DS 6001: Practice and Application of Data Science
#
# ### Instructions
# Please answer the following questions as completely as possible using text, code, and the results of code as needed. Format your answers in a Jupyter notebook. To receive full credit, make sure you address every part of the problem, and make sure your document is formatted in a clean and professional way.
#
# In this lab, you will be working with the [2017 Workplace Health in America survey](https://www.cdc.gov/workplacehealthpromotion/survey/data.html) which was conducted by the Centers for Disease Control and Prevention. According to the survey's [guidence document](https://www.cdc.gov/workplacehealthpromotion/data-surveillance/docs/2017-WHA-Guidance-Document-for-Use-of-Public-Data-files-508.pdf):
#
# > The Workplace Health in America (WHA) Survey gathered information from a cross-sectional, nationally representative sample of US worksites. The sample was drawn from the Dun & Bradstreet (D&B) database of all private and public employers in the United States with at least 10 employees. Like previous national surveys, the worksite served as the sampling unit rather than the companies or firms to which the worksites belonged. Worksites were selected using a stratified simple random sample (SRS) design, where the primary strata were ten multi-state regions defined by the Centers for Disease Control and Prevention (CDC), plus an additional stratum containing all hospital worksites.
#
# The data contain over 300 features that report the industry and type of company where the respondents are employed, what kind of health insurance and other health programs are offered, and other characteristics of the workplaces including whether employees are allowed to work from home and the gender and age makeup of the workforce. The data are full of interesting information, but in order to make use of the data a great deal of data manipulation is required first.

# %% [markdown]
# ## Problem 0
# Import the following libraries:

# %%
import numpy as np
import pandas as pd
import sidetable
import sqlite3
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Problem 1
# The raw data are stored in an ASCII file on the 2017 Workplace Health in America survey [homepage](https://www.cdc.gov/workplacehealthpromotion/survey/data.html). Load the raw data directly into Python without downloading the data onto your harddrive and display a dataframe with only the 14th, 28th, and 102nd rows of the data. [1 point]

# %%
data = pd.read_csv("https://www.cdc.gov/workplacehealthpromotion/data-surveillance/docs/whpps_120717.csv",
                  delimiter="~")

# %%
data.iloc[[13,27,101]]
# Out:
#     OC1  OC3  HI1  HI2  HI3  HI4  HRA1  HRA1A  HRA1B  HRA1E  ...  WL3_05  \
# 13    3  1.0  2.0  3.0  2.0  1.0   1.0    3.0    3.0    1.0  ...     NaN
# 27    1  3.0  1.0  3.0  1.0  1.0   1.0    2.0    4.0    2.0  ...     NaN
# 101   2  1.0  1.0  3.0  2.0  1.0   1.0    2.0    4.0    2.0  ...     NaN
#
#      E1_09  Suppquex       Id  Region  CDC_Region  Industry  Size  Varstrata  \
# 13     NaN       1.0   1437.0     4.0         6.0       7.0   3.0        0.0
# 27     NaN       1.0   2501.0     2.0         4.0       7.0   8.0        0.0
# 101    NaN       2.0  12636.0     4.0         6.0       7.0   4.0        0.0
#
#      Finalwt_worksite,,,,
# 13       47.793940929,,,,
# 27       47.793940929,,,,
# 101      47.793940929,,,,
#
# [3 rows x 301 columns]

# %% [markdown]
# ## Problem 2
# The data contain 301 columns. Create a new variable in Python's memory to store a working version of the data. In the working version, delete all of the columns except for the following:
#
# * `Industry`: 7 Industry Categories with NAICS codes
#
# * `Size`: 8 Employee Size Categories
#
# * `OC3` Is your organization for profit, non-profit, government?
#
# * `HI1` In general, do you offer full, partial or no payment of premiums for personal health insurance for full-time employees?
#
# * `HI2` Over the past 12 months, were full-time employees asked to pay a larger proportion, smaller proportion or the same proportion of personal health insurance premiums?
#
# * `HI3`: Does your organization offer personal health insurance for your part-time employees?
#
# * `CP1`: Are there health education programs, which focus on skill development and lifestyle behavior change along with information dissemination and awareness building?
#
# * `WL6`: Allow employees to work from home?
#
# * Every column that begins `WD`, expressing the percentage of employees that have certain characteristics at the firm
#
# [1 point]

# %%
dfcols = ["Industry", "Size", "OC3", "HI1", "HI2", "HI3", "CP1", "WL6"]+list(data.columns[data.columns.str.startswith("WD")])

# %%
df = data.loc[:,dfcols]

# %%
df.head()
# Out:
#    Industry  Size  OC3  HI1  HI2  HI3  CP1  WL6  WD1_1  WD1_2    WD2    WD3  \
# 0       7.0   7.0  3.0  2.0  1.0  2.0  1.0  1.0   25.0   20.0   85.0   60.0
# 1       7.0   6.0  3.0  2.0  3.0  1.0  1.0  1.0  997.0  997.0   90.0   90.0
# 2       7.0   8.0  3.0  1.0  3.0  1.0  1.0  1.0   35.0    4.0  997.0  997.0
# 3       7.0   4.0  2.0  1.0  2.0  1.0  2.0  2.0   50.0   15.0   50.0   85.0
# 4       7.0   4.0  3.0  1.0  3.0  1.0  1.0  1.0   50.0   40.0   60.0   60.0
#
#      WD4    WD5    WD6    WD7
# 0   40.0   15.0    0.0   22.0
# 1  997.0  997.0    0.0  997.0
# 2   40.0   15.0  997.0  997.0
# 3   75.0    0.0    0.0  997.0
# 4   40.0   30.0    0.0   28.0

# %% [markdown]
# ## Problem 3
# The [codebook](https://www.cdc.gov/workplacehealthpromotion/data-surveillance/docs/2017-WHA-Datafile-Codebook-508.pdf) for the WHA data contain short descriptions of the meaning of each of the columns in the data. Use these descriptions to decide on better and more intuitive names for the columns in the working version of the data, and rename the columns accordingly. [1 point]

# %%
["Industry", "Size", "OC3", "HI1", "HI2", "HI3", "CP1", "WL6"]+list(data.columns[data.columns.str.startswith("WD")])
# Out:
# ['Industry',
#  'Size',
#  'OC3',
#  'HI1',
#  'HI2',
#  'HI3',
#  'CP1',
#  'WL6',
#  'WD1_1',
#  'WD1_2',
#  'WD2',
#  'WD3',
#  'WD4',
#  'WD5',
#  'WD6',
#  'WD7']

# %%
newcols = {
    'Industry': 'Industry',
    'Size': 'Employee_Size',
    'OC3': 'Organization_Type_Profit',
    'HI1': 'Health_Insur_Type',
    'HI2': 'Personal_Health_Insur',
    'HI3': 'Health_Insur_PT',
    'CP1': 'Edu_Programs',
    'WL6': 'Work_From_Home_Allowed',
    'WD1_1':'Under_30',
    'WD1_2': 'Plus_60',
    'WD2': 'Sex_F',
    'WD3': 'Hourly/Non-exempt',
    'WD4': 'No_Daytime_Shift',
    'WD5': 'Remote/Off-Site',
    'WD6': 'Unionized',
    'WD7': 'Avg_Annual_Turnover_Per'
}

# %%
df = df.rename(columns=newcols)

# %%
df.head().T
# Out:
#                              0      1      2      3     4
# Industry                   7.0    7.0    7.0    7.0   7.0
# Employee_Size              7.0    6.0    8.0    4.0   4.0
# Organization_Type_Profit   3.0    3.0    3.0    2.0   3.0
# Health_Insur_Type          2.0    2.0    1.0    1.0   1.0
# Personal_Health_Insur      1.0    3.0    3.0    2.0   3.0
# Health_Insur_PT            2.0    1.0    1.0    1.0   1.0
# Edu_Programs               1.0    1.0    1.0    2.0   1.0
# Work_From_Home_Allowed     1.0    1.0    1.0    2.0   1.0
# Under_30                  25.0  997.0   35.0   50.0  50.0
# Plus_60                   20.0  997.0    4.0   15.0  40.0
# Sex_F                     85.0   90.0  997.0   50.0  60.0
# Hourly/Non-exempt         60.0   90.0  997.0   85.0  60.0
# No_Daytime_Shift          40.0  997.0   40.0   75.0  40.0
# Remote/Off-Site           15.0  997.0   15.0    0.0  30.0
# Unionized                  0.0    0.0  997.0    0.0   0.0
# Avg_Annual_Turnover_Per   22.0  997.0  997.0  997.0  28.0

# %% [markdown]
# ## Problem 4
# Using the codebook and this [dictionary of NAICS industrial codes](https://www.naics.com/search-naics-codes-by-industry/), place descriptive labels on the categories of the industry column in the working data. [1 point]

# %%
df["Industry"].isna().sum()
# Out:
# 1

# %%
df["Industry"].fillna(0, inplace=True)

# %%
df["Industry"].isna().sum()
# Out:
# 0

# %%
industry_codes = {"Industry":{
    1: "Manual Labor and Resources",
    2: "Trade, Transportion, Warehousing",
    3: "Arts and Customer Service",
    4: "Business and Finance",
    5: "Public Services",
    6: "Public Admin",
    7: "Hospital Worksites",
    0: "Unrecorded"
}}

# %%
df = df.replace(industry_codes)

# %%
df.head().T
# Out:
#                                            0                   1  \
# Industry                  Hospital Worksites  Hospital Worksites
# Employee_Size                            7.0                 6.0
# Organization_Type_Profit                 3.0                 3.0
# Health_Insur_Type                        2.0                 2.0
# Personal_Health_Insur                    1.0                 3.0
# Health_Insur_PT                          2.0                 1.0
# Edu_Programs                             1.0                 1.0
# Work_From_Home_Allowed                   1.0                 1.0
# Under_30                                25.0               997.0
# Plus_60                                 20.0               997.0
# Sex_F                                   85.0                90.0
# Hourly/Non-exempt                       60.0                90.0
# No_Daytime_Shift                        40.0               997.0
# Remote/Off-Site                         15.0               997.0
# Unionized                                0.0                 0.0
# Avg_Annual_Turnover_Per                 22.0               997.0
#
#                                            2                   3  \
# Industry                  Hospital Worksites  Hospital Worksites
# Employee_Size                            8.0                 4.0
# Organization_Type_Profit                 3.0                 2.0
# Health_Insur_Type                        1.0                 1.0
# Personal_Health_Insur                    3.0                 2.0
# Health_Insur_PT                          1.0                 1.0
# Edu_Programs                             1.0                 2.0
# Work_From_Home_Allowed                   1.0                 2.0
# Under_30                                35.0                50.0
# Plus_60                                  4.0                15.0
# Sex_F                                  997.0                50.0
# Hourly/Non-exempt                      997.0                85.0
# No_Daytime_Shift                        40.0                75.0
# Remote/Off-Site                         15.0                 0.0
# Unionized                              997.0                 0.0
# Avg_Annual_Turnover_Per                997.0               997.0
#
#                                            4
# Industry                  Hospital Worksites
# Employee_Size                            4.0
# Organization_Type_Profit                 3.0
# Health_Insur_Type                        1.0
# Personal_Health_Insur                    3.0
# Health_Insur_PT                          1.0
# Edu_Programs                             1.0
# Work_From_Home_Allowed                   1.0
# Under_30                                50.0
# Plus_60                                 40.0
# Sex_F                                   60.0
# Hourly/Non-exempt                       60.0
# No_Daytime_Shift                        40.0
# Remote/Off-Site                         30.0
# Unionized                                0.0
# Avg_Annual_Turnover_Per                 28.0

# %% [markdown]
# ## Problem 5
# Using the codebook, recode the "size" column to have three categories: "Small" for workplaces with fewer than 100 employees, "Medium" for workplaces with at least 100 but fewer than 500 employees, and "Large" for companies with at least 500 employees. [Note: Python dataframes have an attribute `.size` that reports the space the dataframe takes up in memory. Don't confuse this attribute with the column named "Size" in the raw data.] [1 point]

# %%
df["Employee_Size"] = df["Employee_Size"].replace([[1,2,3], [4,5], [6,7,8]], ["Small", "Medium", "Large"])
df["Employee_Size"].value_counts()
# Out:
# Employee_Size
# Small     2195
# Medium     393
# Large      254
# Name: count, dtype: int64

# %%
df.head().T
# Out:
#                                            0                   1  \
# Industry                  Hospital Worksites  Hospital Worksites
# Employee_Size                          Large               Large
# Organization_Type_Profit                 3.0                 3.0
# Health_Insur_Type                        2.0                 2.0
# Personal_Health_Insur                    1.0                 3.0
# Health_Insur_PT                          2.0                 1.0
# Edu_Programs                             1.0                 1.0
# Work_From_Home_Allowed                   1.0                 1.0
# Under_30                                25.0               997.0
# Plus_60                                 20.0               997.0
# Sex_F                                   85.0                90.0
# Hourly/Non-exempt                       60.0                90.0
# No_Daytime_Shift                        40.0               997.0
# Remote/Off-Site                         15.0               997.0
# Unionized                                0.0                 0.0
# Avg_Annual_Turnover_Per                 22.0               997.0
#
#                                            2                   3  \
# Industry                  Hospital Worksites  Hospital Worksites
# Employee_Size                          Large              Medium
# Organization_Type_Profit                 3.0                 2.0
# Health_Insur_Type                        1.0                 1.0
# Personal_Health_Insur                    3.0                 2.0
# Health_Insur_PT                          1.0                 1.0
# Edu_Programs                             1.0                 2.0
# Work_From_Home_Allowed                   1.0                 2.0
# Under_30                                35.0                50.0
# Plus_60                                  4.0                15.0
# Sex_F                                  997.0                50.0
# Hourly/Non-exempt                      997.0                85.0
# No_Daytime_Shift                        40.0                75.0
# Remote/Off-Site                         15.0                 0.0
# Unionized                              997.0                 0.0
# Avg_Annual_Turnover_Per                997.0               997.0
#
#                                            4
# Industry                  Hospital Worksites
# Employee_Size                         Medium
# Organization_Type_Profit                 3.0
# Health_Insur_Type                        1.0
# Personal_Health_Insur                    3.0
# Health_Insur_PT                          1.0
# Edu_Programs                             1.0
# Work_From_Home_Allowed                   1.0
# Under_30                                50.0
# Plus_60                                 40.0
# Sex_F                                   60.0
# Hourly/Non-exempt                       60.0
# No_Daytime_Shift                        40.0
# Remote/Off-Site                         30.0
# Unionized                                0.0
# Avg_Annual_Turnover_Per                 28.0

# %% [markdown]
# ## Problem 6
# Use the codebook to write accurate and descriptive labels for each category for each categorical column in the working data. Then apply all of these labels to the data at once. Code "Legitimate Skip", "Don't know", "Refused", and "Blank" as missing values. [2 points]

# %% [markdown]
# **Why do this way when other way is faster**
#
# code_book = {'Organization_Type_Profit': {1: 'For Profit, Public',
#                       2: 'For Profit, Private',3: 'Non-Profit',
#                       4: 'State or Local Govt',
#                       5: 'Federal Govt',
#                       6: 'Other',
#                       97: np.nan,
#                       98: np.nan,
#                       99: np.nan},
#             'Health_Insur_Type': {1: 'Full',
#                                           2: 'Partial',
#                                           3: 'No',
#                                           97: np.nan,
#                                           98: np.nan,
#                                           99: np.nan},
#             'Personal_Health_Insur': {1: 'Larger',
#                                          2: 'Smaller',
#                                          3: 'About Same',
#                                          96: np.nan,
#                                          97: np.nan,
#                                          98: np.nan,
#                                          99: np.nan},
#             'Health_Insur_PT': {1: 'Yes',
#                                            2: 'No',
#                                            97: np.nan,
#                                            98: np.nan,
#                                            99: np.nan},
#             'Edu_Programs': {1: 'Yes',
#                                          2: 'No',
#                                          97: np.nan,
#                                          98: np.nan,
#                                          99: np.nan},
#             'Work_From_Home_Allowed': {1: 'Yes',
#                     2: 'No',
#                     97: np.nan,
#                     98: np.nan,
#                     99: np.nan}}
#
# df = df.replace(code_book)

# %%
df["Organization_Type_Profit"] = df["Organization_Type_Profit"].replace([1,2,3,4,5,6, [97,98,99]],
                                                                       ["for profit-public", "for profit-private", "non-profit", 
                                                                        "state or local govt", "fed govt", "other", np.nan])
df["Organization_Type_Profit"].value_counts()
# Out:
# Organization_Type_Profit
# for profit-private     1199
# non-profit              632
# state or local govt     378
# for profit-public       317
# other                    51
# fed govt                 36
# Name: count, dtype: int64

# %%
df["Organization_Type_Profit"].isna().sum()
# Out:
# 230

# %%
df["Health_Insur_Type"] = df["Health_Insur_Type"].replace([1,2,3,[97,98,99]],
                                                          ["Full","Partial","No",np.nan])

# %%
df["Personal_Health_Insur"] = df["Personal_Health_Insur"].replace([1,2,3,[96, 97, 98, 99]], 
                                                                  ["Larger", "Smaller", "About the same", np.nan])

# %%
df["Health_Insur_PT"] = df["Health_Insur_PT"].replace([1,2,[97,98,99]],
                                                        ["yes","no",np.nan])

# %%
df["Edu_Programs"] = df["Edu_Programs"].replace([1,2,[97,98,99]],
                                                        ["yes","no",np.nan])

# %%
df["Work_From_Home_Allowed"] = df["Work_From_Home_Allowed"].replace([1,2,[97,98,99]],
                                                        ["yes","no",np.nan])

# %%
df.head().T
# Out:
#                                            0                   1  \
# Industry                  Hospital Worksites  Hospital Worksites
# Employee_Size                          Large               Large
# Organization_Type_Profit          non-profit          non-profit
# Health_Insur_Type                    Partial             Partial
# Personal_Health_Insur                 Larger      About the same
# Health_Insur_PT                           no                 yes
# Edu_Programs                             yes                 yes
# Work_From_Home_Allowed                   yes                 yes
# Under_30                                25.0               997.0
# Plus_60                                 20.0               997.0
# Sex_F                                   85.0                90.0
# Hourly/Non-exempt                       60.0                90.0
# No_Daytime_Shift                        40.0               997.0
# Remote/Off-Site                         15.0               997.0
# Unionized                                0.0                 0.0
# Avg_Annual_Turnover_Per                 22.0               997.0
#
#                                            2                   3  \
# Industry                  Hospital Worksites  Hospital Worksites
# Employee_Size                          Large              Medium
# Organization_Type_Profit          non-profit  for profit-private
# Health_Insur_Type                       Full                Full
# Personal_Health_Insur         About the same             Smaller
# Health_Insur_PT                          yes                 yes
# Edu_Programs                             yes                  no
# Work_From_Home_Allowed                   yes                  no
# Under_30                                35.0                50.0
# Plus_60                                  4.0                15.0
# Sex_F                                  997.0                50.0
# Hourly/Non-exempt                      997.0                85.0
# No_Daytime_Shift                        40.0                75.0
# Remote/Off-Site                         15.0                 0.0
# Unionized                              997.0                 0.0
# Avg_Annual_Turnover_Per                997.0               997.0
#
#                                            4
# Industry                  Hospital Worksites
# Employee_Size                         Medium
# Organization_Type_Profit          non-profit
# Health_Insur_Type                       Full
# Personal_Health_Insur         About the same
# Health_Insur_PT                          yes
# Edu_Programs                             yes
# Work_From_Home_Allowed                   yes
# Under_30                                50.0
# Plus_60                                 40.0
# Sex_F                                   60.0
# Hourly/Non-exempt                       60.0
# No_Daytime_Shift                        40.0
# Remote/Off-Site                         30.0
# Unionized                                0.0
# Avg_Annual_Turnover_Per                 28.0

# %% [markdown]
# ## Problem 7
# The features that measure the percent of the workforce with a particular characteristic use the codes 997, 998, and 999 to represent "Don't know", "Refusal", and "Blank/Invalid" respectively. Replace these values with missing values for all of the percentage features at the same time. [1 point]

# %%
df = df.replace([997,998,999],
                np.nan)

# %%
df.head().T
# Out:
#                                            0                   1  \
# Industry                  Hospital Worksites  Hospital Worksites
# Employee_Size                          Large               Large
# Organization_Type_Profit          non-profit          non-profit
# Health_Insur_Type                    Partial             Partial
# Personal_Health_Insur                 Larger      About the same
# Health_Insur_PT                           no                 yes
# Edu_Programs                             yes                 yes
# Work_From_Home_Allowed                   yes                 yes
# Under_30                                25.0                 NaN
# Plus_60                                 20.0                 NaN
# Sex_F                                   85.0                90.0
# Hourly/Non-exempt                       60.0                90.0
# No_Daytime_Shift                        40.0                 NaN
# Remote/Off-Site                         15.0                 NaN
# Unionized                                0.0                 0.0
# Avg_Annual_Turnover_Per                 22.0                 NaN
#
#                                            2                   3  \
# Industry                  Hospital Worksites  Hospital Worksites
# Employee_Size                          Large              Medium
# Organization_Type_Profit          non-profit  for profit-private
# Health_Insur_Type                       Full                Full
# Personal_Health_Insur         About the same             Smaller
# Health_Insur_PT                          yes                 yes
# Edu_Programs                             yes                  no
# Work_From_Home_Allowed                   yes                  no
# Under_30                                35.0                50.0
# Plus_60                                  4.0                15.0
# Sex_F                                    NaN                50.0
# Hourly/Non-exempt                        NaN                85.0
# No_Daytime_Shift                        40.0                75.0
# Remote/Off-Site                         15.0                 0.0
# Unionized                                NaN                 0.0
# Avg_Annual_Turnover_Per                  NaN                 NaN
#
#                                            4
# Industry                  Hospital Worksites
# Employee_Size                         Medium
# Organization_Type_Profit          non-profit
# Health_Insur_Type                       Full
# Personal_Health_Insur         About the same
# Health_Insur_PT                          yes
# Edu_Programs                             yes
# Work_From_Home_Allowed                   yes
# Under_30                                50.0
# Plus_60                                 40.0
# Sex_F                                   60.0
# Hourly/Non-exempt                       60.0
# No_Daytime_Shift                        40.0
# Remote/Off-Site                         30.0
# Unionized                                0.0
# Avg_Annual_Turnover_Per                 28.0

# %%
df.isna().sum()
# Out:
# Industry                       0
# Employee_Size                  1
# Organization_Type_Profit     230
# Health_Insur_Type             80
# Personal_Health_Insur        594
# Health_Insur_PT              161
# Edu_Programs                 175
# Work_From_Home_Allowed       294
# Under_30                     969
# Plus_60                      942
# Sex_F                        796
# Hourly/Non-exempt            936
# No_Daytime_Shift             857
# Remote/Off-Site              785
# Unionized                    692
# Avg_Annual_Turnover_Per     1286
# dtype: int64

# %% [markdown]
# ## Problem 8
# Sort the working data by industry in ascending alphabetical order. Within industry categories, sort the rows by size in ascending alphabetical order. Within groups with the same industry and size, sort by percent of the workforce that is under 30 in descending numeric order. [1 point]

# %%
df.sort_values(by=["Industry", "Employee_Size", "Under_30"], ascending=[True, True, False])\
.groupby(["Industry", "Employee_Size"]).head().T
# Out:
#                                                2431  \
# Industry                  Arts and Customer Service
# Employee_Size                                 Large
# Organization_Type_Profit         for profit-private
# Health_Insur_Type                           Partial
# Personal_Health_Insur                       Smaller
# Health_Insur_PT                                  no
# Edu_Programs                                     no
# Work_From_Home_Allowed                           no
# Under_30                                       70.0
# Plus_60                                         5.0
# Sex_F                                          25.0
# Hourly/Non-exempt                              95.0
# No_Daytime_Shift                               15.0
# Remote/Off-Site                                 0.0
# Unionized                                       0.0
# Avg_Annual_Turnover_Per                        45.0
# gender_balance                           mostly men
#
#                                                1035  \
# Industry                  Arts and Customer Service
# Employee_Size                                 Large
# Organization_Type_Profit                 non-profit
# Health_Insur_Type                           Partial
# Personal_Health_Insur                       Smaller
# Health_Insur_PT                                 yes
# Edu_Programs                                    yes
# Work_From_Home_Allowed                          yes
# Under_30                                       65.0
# Plus_60                                        15.0
# Sex_F                                          65.0
# Hourly/Non-exempt                              70.0
# No_Daytime_Shift                                4.0
# Remote/Off-Site                                 4.0
# Unionized                                       0.0
# Avg_Annual_Turnover_Per                         NaN
# gender_balance                             balanced
#
#                                                2680  \
# Industry                  Arts and Customer Service
# Employee_Size                                 Large
# Organization_Type_Profit                      other
# Health_Insur_Type                              Full
# Personal_Health_Insur                About the same
# Health_Insur_PT                                  no
# Edu_Programs                                     no
# Work_From_Home_Allowed                           no
# Under_30                                       65.0
# Plus_60                                        20.0
# Sex_F                                          50.0
# Hourly/Non-exempt                              85.0
# No_Daytime_Shift                               60.0
# Remote/Off-Site                                 0.0
# Unionized                                       0.0
# Avg_Annual_Turnover_Per                        10.0
# gender_balance                             balanced
#
#                                                1308  \
# Industry                  Arts and Customer Service
# Employee_Size                                 Large
# Organization_Type_Profit                        NaN
# Health_Insur_Type                           Partial
# Personal_Health_Insur                About the same
# Health_Insur_PT                                  no
# Edu_Programs                                     no
# Work_From_Home_Allowed                           no
# Under_30                                       60.0
# Plus_60                                         5.0
# Sex_F                                          70.0
# Hourly/Non-exempt                              75.0
# No_Daytime_Shift                               10.0
# Remote/Off-Site                                 0.0
# Unionized                                       0.0
# Avg_Annual_Turnover_Per                        60.0
# gender_balance                         mostly women
#
#                                                777   \
# Industry                  Arts and Customer Service
# Employee_Size                                 Large
# Organization_Type_Profit        state or local govt
# Health_Insur_Type                           Partial
# Personal_Health_Insur                        Larger
# Health_Insur_PT                                 yes
# Edu_Programs                                    yes
# Work_From_Home_Allowed                          yes
# Under_30                                       25.0
# Plus_60                                        35.0
# Sex_F                                          55.0
# Hourly/Non-exempt                               NaN
# No_Daytime_Shift                                NaN
# Remote/Off-Site                                 NaN
# Unionized                                       NaN
# Avg_Annual_Turnover_Per                         NaN
# gender_balance                             balanced
#
#                                                778   \
# Industry                  Arts and Customer Service
# Employee_Size                                Medium
# Organization_Type_Profit          for profit-public
# Health_Insur_Type                           Partial
# Personal_Health_Insur                About the same
# Health_Insur_PT                                 yes
# Edu_Programs                                     no
# Work_From_Home_Allowed                           no
# Under_30                                       80.0
# Plus_60                                         0.0
# Sex_F                                          60.0
# Hourly/Non-exempt                              80.0
# No_Daytime_Shift                              100.0
# Remote/Off-Site                                 3.0
# Unionized                                       0.0
# Avg_Annual_Turnover_Per                        10.0
# gender_balance                             balanced
#
#                                                2177  \
# Industry                  Arts and Customer Service
# Employee_Size                                Medium
# Organization_Type_Profit        state or local govt
# Health_Insur_Type                           Partial
# Personal_Health_Insur                About the same
# Health_Insur_PT                                  no
# Edu_Programs                                    yes
# Work_From_Home_Allowed                           no
# Under_30                                       80.0
# Plus_60                                        10.0
# Sex_F                                          50.0
# Hourly/Non-exempt                              90.0
# No_Daytime_Shift                               70.0
# Remote/Off-Site                                80.0
# Unionized                                       0.0
# Avg_Annual_Turnover_Per                         NaN
# gender_balance                             balanced
#
#                                                2178  \
# Industry                  Arts and Customer Service
# Employee_Size                                Medium
# Organization_Type_Profit         for profit-private
# Health_Insur_Type                           Partial
# Personal_Health_Insur                About the same
# Health_Insur_PT                                  no
# Edu_Programs                                     no
# Work_From_Home_Allowed                          yes
# Under_30                                       70.0
# Plus_60                                         1.0
# Sex_F                                          50.0
# Hourly/Non-exempt                              85.0
# No_Daytime_Shift                               60.0
# Remote/Off-Site                                 5.0
# Unionized                                       NaN
# Avg_Annual_Turnover_Per                        70.0
# gender_balance                             balanced
#
#                                                2179  \
# Industry                  Arts and Customer Service
# Employee_Size                                Medium
# Organization_Type_Profit          for profit-public
# Health_Insur_Type                                No
# Personal_Health_Insur                           NaN
# Health_Insur_PT                                  no
# Edu_Programs                                     no
# Work_From_Home_Allowed                          yes
# Under_30                                       65.0
# Plus_60                                         0.0
# Sex_F                                          50.0
# Hourly/Non-exempt                              90.0
# No_Daytime_Shift                               80.0
# Remote/Off-Site                                 0.0
# Unionized                                       0.0
# Avg_Annual_Turnover_Per                        40.0
# gender_balance                             balanced
#
#                                                1558  ...  \
# Industry                  Arts and Customer Service  ...
# Employee_Size                                Medium  ...
# Organization_Type_Profit         for profit-private  ...
# Health_Insur_Type                           Partial  ...
# Personal_Health_Insur                        Larger  ...
# Health_Insur_PT                                  no  ...
# Edu_Programs                                     no  ...
# Work_From_Home_Allowed                           no  ...
# Under_30                                       50.0  ...
# Plus_60                                        10.0  ...
# Sex_F                                          70.0  ...
# Hourly/Non-exempt                              80.0  ...
# No_Daytime_Shift                               60.0  ...
# Remote/Off-Site                                 0.0  ...
# Unionized                                       0.0  ...
# Avg_Annual_Turnover_Per                        60.0  ...
# gender_balance                         mostly women  ...
#
#                                                       972   \
# Industry                  Trade, Transportion, Warehousing
# Employee_Size                                       Medium
# Organization_Type_Profit                for profit-private
# Health_Insur_Type                                  Partial
# Personal_Health_Insur                       About the same
# Health_Insur_PT                                         no
# Edu_Programs                                            no
# Work_From_Home_Allowed                                  no
# Under_30                                              70.0
# Plus_60                                               30.0
# Sex_F                                                 15.0
# Hourly/Non-exempt                                     85.0
# No_Daytime_Shift                                       0.0
# Remote/Off-Site                                        0.0
# Unionized                                              0.0
# Avg_Annual_Turnover_Per                                NaN
# gender_balance                                  mostly men
#
#                                                       1509  \
# Industry                  Trade, Transportion, Warehousing
# Employee_Size                                       Medium
# Organization_Type_Profit                 for profit-public
# Health_Insur_Type                                     Full
# Personal_Health_Insur                               Larger
# Health_Insur_PT                                        yes
# Edu_Programs                                           yes
# Work_From_Home_Allowed                                  no
# Under_30                                              70.0
# Plus_60                                                5.0
# Sex_F                                                 50.0
# Hourly/Non-exempt                                     90.0
# No_Daytime_Shift                                      75.0
# Remote/Off-Site                                        0.0
# Unionized                                             50.0
# Avg_Annual_Turnover_Per                               95.0
# gender_balance                                    balanced
#
#                                                       2393  \
# Industry                  Trade, Transportion, Warehousing
# Employee_Size                                       Medium
# Organization_Type_Profit                for profit-private
# Health_Insur_Type                                  Partial
# Personal_Health_Insur                       About the same
# Health_Insur_PT                                         no
# Edu_Programs                                           yes
# Work_From_Home_Allowed                                 yes
# Under_30                                              57.0
# Plus_60                                               15.0
# Sex_F                                                 60.0
# Hourly/Non-exempt                                     80.0
# No_Daytime_Shift                                      25.0
# Remote/Off-Site                                       15.0
# Unionized                                              0.0
# Avg_Annual_Turnover_Per                               40.0
# gender_balance                                    balanced
#
#                                                       2621  \
# Industry                  Trade, Transportion, Warehousing
# Employee_Size                                       Medium
# Organization_Type_Profit                for profit-private
# Health_Insur_Type                                     Full
# Personal_Health_Insur                       About the same
# Health_Insur_PT                                        yes
# Edu_Programs                                           yes
# Work_From_Home_Allowed                                 yes
# Under_30                                              56.0
# Plus_60                                                2.0
# Sex_F                                                 39.0
# Hourly/Non-exempt                                     57.0
# No_Daytime_Shift                                       0.0
# Remote/Off-Site                                       20.0
# Unionized                                              0.0
# Avg_Annual_Turnover_Per                                9.0
# gender_balance                                    balanced
#
#                                                       1772  \
# Industry                  Trade, Transportion, Warehousing
# Employee_Size                                       Medium
# Organization_Type_Profit                 for profit-public
# Health_Insur_Type                                     Full
# Personal_Health_Insur                       About the same
# Health_Insur_PT                                         no
# Edu_Programs                                           NaN
# Work_From_Home_Allowed                                  no
# Under_30                                              50.0
# Plus_60                                               15.0
# Sex_F                                                 75.0
# Hourly/Non-exempt                                     85.0
# No_Daytime_Shift                                      50.0
# Remote/Off-Site                                        0.0
# Unionized                                              NaN
# Avg_Annual_Turnover_Per                                NaN
# gender_balance                                mostly women
#
#                                                       554   \
# Industry                  Trade, Transportion, Warehousing
# Employee_Size                                        Small
# Organization_Type_Profit                for profit-private
# Health_Insur_Type                                      NaN
# Personal_Health_Insur                                  NaN
# Health_Insur_PT                                         no
# Edu_Programs                                           yes
# Work_From_Home_Allowed                                 yes
# Under_30                                             100.0
# Plus_60                                                0.0
# Sex_F                                                 75.0
# Hourly/Non-exempt                                     80.0
# No_Daytime_Shift                                       0.0
# Remote/Off-Site                                        0.0
# Unionized                                              0.0
# Avg_Annual_Turnover_Per                                NaN
# gender_balance                                mostly women
#
#                                                       1494  \
# Industry                  Trade, Transportion, Warehousing
# Employee_Size                                        Small
# Organization_Type_Profit                 for profit-public
# Health_Insur_Type                                     Full
# Personal_Health_Insur                       About the same
# Health_Insur_PT                                         no
# Edu_Programs                                            no
# Work_From_Home_Allowed                                  no
# Under_30                                             100.0
# Plus_60                                                0.0
# Sex_F                                                 97.0
# Hourly/Non-exempt                                     99.0
# No_Daytime_Shift                                       0.0
# Remote/Off-Site                                        2.0
# Unionized                                              0.0
# Avg_Annual_Turnover_Per                                5.0
# gender_balance                                mostly women
#
#                                                       956   \
# Industry                  Trade, Transportion, Warehousing
# Employee_Size                                        Small
# Organization_Type_Profit                               NaN
# Health_Insur_Type                                     Full
# Personal_Health_Insur                       About the same
# Health_Insur_PT                                         no
# Edu_Programs                                            no
# Work_From_Home_Allowed                                  no
# Under_30                                              95.0
# Plus_60                                                5.0
# Sex_F                                                 85.0
# Hourly/Non-exempt                                     97.0
# No_Daytime_Shift                                       0.0
# Remote/Off-Site                                        0.0
# Unionized                                              0.0
# Avg_Annual_Turnover_Per                                NaN
# gender_balance                                mostly women
#
#                                                       1765  \
# Industry                  Trade, Transportion, Warehousing
# Employee_Size                                        Small
# Organization_Type_Profit                 for profit-public
# Health_Insur_Type                                  Partial
# Personal_Health_Insur                       About the same
# Health_Insur_PT                                         no
# Edu_Programs                                           yes
# Work_From_Home_Allowed                                 yes
# Under_30                                              95.0
# Plus_60                                                1.0
# Sex_F                                                 50.0
# Hourly/Non-exempt                                     90.0
# No_Daytime_Shift                                      50.0
# Remote/Off-Site                                        5.0
# Unionized                                              0.0
# Avg_Annual_Turnover_Per                                NaN
# gender_balance                                    balanced
#
#                                                       2373
# Industry                  Trade, Transportion, Warehousing
# Employee_Size                                        Small
# Organization_Type_Profit                for profit-private
# Health_Insur_Type                                     Full
# Personal_Health_Insur                       About the same
# Health_Insur_PT                                         no
# Edu_Programs                                            no
# Work_From_Home_Allowed                                  no
# Under_30                                              90.0
# Plus_60                                                0.0
# Sex_F                                                 40.0
# Hourly/Non-exempt                                    100.0
# No_Daytime_Shift                                      80.0
# Remote/Off-Site                                        0.0
# Unionized                                              0.0
# Avg_Annual_Turnover_Per                               10.0
# gender_balance                                    balanced
#
# [17 rows x 105 columns]

# %% [markdown]
# ## Problem 9
# There is one row in the working data that has a `NaN` value for industry. Delete this row. Use a logical expression, and not the row number. [1 point]

# %%
df.dropna(how='all')
df[-5:]
# Out:
#           Industry Employee_Size Organization_Type_Profit Health_Insur_Type  \
# 2838  Public Admin        Medium      state or local govt              Full
# 2839  Public Admin        Medium      state or local govt           Partial
# 2840  Public Admin         Large      state or local govt           Partial
# 2841  Public Admin         Large      state or local govt           Partial
# 2842  Public Admin         Large      state or local govt           Partial
#
#      Personal_Health_Insur Health_Insur_PT Edu_Programs  \
# 2838        About the same             yes          yes
# 2839        About the same             yes          yes
# 2840        About the same             yes          yes
# 2841        About the same             yes           no
# 2842        About the same             yes          yes
#
#      Work_From_Home_Allowed  Under_30  Plus_60  Sex_F  Hourly/Non-exempt  \
# 2838                    NaN       NaN      NaN    NaN                NaN
# 2839                     no       NaN      NaN    NaN                NaN
# 2840                    yes      27.0      NaN   61.0                NaN
# 2841                    NaN       NaN      NaN    NaN                NaN
# 2842                    yes      25.0     10.0   35.0               90.0
#
#       No_Daytime_Shift  Remote/Off-Site  Unionized  Avg_Annual_Turnover_Per
# 2838               NaN              NaN        NaN                      NaN
# 2839               NaN              NaN        NaN                      NaN
# 2840               NaN              NaN        NaN                      NaN
# 2841               NaN              NaN        NaN                      NaN
# 2842              25.0             60.0       80.0                      NaN

# %% [markdown]
# ## Problem 10
# Create a new feature named `gender_balance` that has three categories: "Mostly men" for workplaces with between 0% and 35% female employees, "Balanced" for workplaces with more than 35% and at most 65% female employees, and "Mostly women" for workplaces with more than 65% female employees. [1 point]

# %%
df["Sex_F"].unique()
# Out:
# array([ 85.,  90.,  nan,  50.,  60.,  65.,  80.,  75.,  95.,  66.,  82.,
#         89.,  70.,  76.,  68.,  99.,  77.,  88.,  81.,  74.,  55.,  87.,
#         51., 100.,  93.,  25.,  98.,  10.,  78.,  84.,  73.,  58.,  56.,
#         97.,  40.,  30.,   0.,  29.,  20.,   2.,   1.,   5.,  12.,  47.,
#          4.,   3.,  15.,  32.,   7.,  35.,  48.,  52.,   9.,  69.,  72.,
#         13.,  22.,  45.,  49.,  92.,  57.,  34.,  43.,  14.,  23.,  38.,
#         11.,  26.,   8.,  42.,  18.,  96.,  63.,  17.,  27.,  33.,   6.,
#         67.,  54.,  86.,  62.,  24.,  36.,  19.,  71.,  37.,  16.,  44.,
#         83.,  94.,  21.,  39.,  79.,  59.,  53.,  46.,  64.,  31.,  28.,
#         61.,  91.,  41.])

# %%
df["Sex_F"].isna().sum()
# Out:
# 796

# %%
df["gender_balance"] = pd.cut(df.Sex_F, [0, 35, 65, np.inf], 
                              labels=["mostly men", "balanced","mostly women"],
                              include_lowest=True)

# %%
df["gender_balance"].isna().sum()
# Out:
# 796

# %%
df["gender_balance"].value_counts()
# Out:
# gender_balance
# mostly men      733
# mostly women    727
# balanced        587
# Name: count, dtype: int64

# %% [markdown]
# ## Problem 11
# Change the data type of all categorical features in the working data from "object" to "category". [1 point]

# %%
df.columns
# Out:
# Index(['Industry', 'Employee_Size', 'Organization_Type_Profit',
#        'Health_Insur_Type', 'Personal_Health_Insur', 'Health_Insur_PT',
#        'Edu_Programs', 'Work_From_Home_Allowed', 'Under_30', 'Plus_60',
#        'Sex_F', 'Hourly/Non-exempt', 'No_Daytime_Shift', 'Remote/Off-Site',
#        'Unionized', 'Avg_Annual_Turnover_Per', 'gender_balance'],
#       dtype='object')

# %%
cols = ['Organization_Type_Profit',
       'Health_Insur_Type', 'Personal_Health_Insur', 'Health_Insur_PT',
       'Edu_Programs', 'Work_From_Home_Allowed']
df[cols] = df[cols].astype('category')
df.dtypes
# Out:
# Industry                      object
# Employee_Size                 object
# Organization_Type_Profit    category
# Health_Insur_Type           category
# Personal_Health_Insur       category
# Health_Insur_PT             category
# Edu_Programs                category
# Work_From_Home_Allowed      category
# Under_30                     float64
# Plus_60                      float64
# Sex_F                        float64
# Hourly/Non-exempt            float64
# No_Daytime_Shift             float64
# Remote/Off-Site              float64
# Unionized                    float64
# Avg_Annual_Turnover_Per      float64
# gender_balance              category
# dtype: object

# %% [markdown]
# ## Problem 12
# Filter the data to only those rows that represent small workplaces that allow employees to work from home. Then report how many of these workplaces offer full insurance, partial insurance, and no insurance. Use a function that reports the percent, cumulative count, and cumulative percent in addition to the counts. [1 point]

# %%
mq = df.query("Employee_Size=='Small' & Work_From_Home_Allowed=='yes'")
mq.head()
# Out:
#               Industry Employee_Size Organization_Type_Profit  \
# 5   Hospital Worksites         Small               non-profit
# 10  Hospital Worksites         Small               non-profit
# 20  Hospital Worksites         Small               non-profit
# 22  Hospital Worksites         Small               non-profit
# 30  Hospital Worksites         Small               non-profit
#
#    Health_Insur_Type Personal_Health_Insur Health_Insur_PT Edu_Programs  \
# 5               Full        About the same             yes          yes
# 10              Full        About the same             yes          yes
# 20                No                   NaN              no           no
# 22              Full        About the same             yes          yes
# 30           Partial                Larger              no           no
#
#    Work_From_Home_Allowed  Under_30  Plus_60  Sex_F  Hourly/Non-exempt  \
# 5                     yes      20.0     25.0   65.0               80.0
# 10                    yes       NaN      NaN    NaN                NaN
# 20                    yes      20.0     20.0   66.0               90.0
# 22                    yes      25.0      8.0   82.0               83.0
# 30                    yes       NaN      NaN    NaN                NaN
#
#     No_Daytime_Shift  Remote/Off-Site  Unionized  Avg_Annual_Turnover_Per  \
# 5               25.0              5.0        0.0                     15.0
# 10               NaN              NaN        NaN                      NaN
# 20              20.0              5.0        0.0                      5.0
# 22               NaN              NaN        7.0                     15.0
# 30               NaN              NaN        0.0                      NaN
#
#    gender_balance
# 5        balanced
# 10            NaN
# 20   mostly women
# 22   mostly women
# 30            NaN

# %%
mq.stb.freq(["Health_Insur_Type"])
# Out:
#   Health_Insur_Type  count    percent  cumulative_count  cumulative_percent
# 0              Full    324  46.285714               324           46.285714
# 1           Partial    310  44.285714               634           90.571429
# 2                No     66   9.428571               700          100.000000

# %% [markdown]
# ## Problem 13
# Anything that can be done in SQL can be done with `pandas`. The next several questions ask you to write `pandas` code to match a given SQL query. But to check that the SQL query and `pandas` code yield the same result, create a new database wsing the `sqlite3` package and input the cleaned WHA data as a table in this database. (See module 6 for a discussion of SQlite in Python.) [1 point]

# %%
df.head()
# Out:
#              Industry Employee_Size Organization_Type_Profit  \
# 0  Hospital Worksites         Large               non-profit
# 1  Hospital Worksites         Large               non-profit
# 2  Hospital Worksites         Large               non-profit
# 3  Hospital Worksites        Medium       for profit-private
# 4  Hospital Worksites        Medium               non-profit
#
#   Health_Insur_Type Personal_Health_Insur Health_Insur_PT Edu_Programs  \
# 0           Partial                Larger              no          yes
# 1           Partial        About the same             yes          yes
# 2              Full        About the same             yes          yes
# 3              Full               Smaller             yes           no
# 4              Full        About the same             yes          yes
#
#   Work_From_Home_Allowed  Under_30  Plus_60  Sex_F  Hourly/Non-exempt  \
# 0                    yes      25.0     20.0   85.0               60.0
# 1                    yes       NaN      NaN   90.0               90.0
# 2                    yes      35.0      4.0    NaN                NaN
# 3                     no      50.0     15.0   50.0               85.0
# 4                    yes      50.0     40.0   60.0               60.0
#
#    No_Daytime_Shift  Remote/Off-Site  Unionized  Avg_Annual_Turnover_Per  \
# 0              40.0             15.0        0.0                     22.0
# 1               NaN              NaN        0.0                      NaN
# 2              40.0             15.0        NaN                      NaN
# 3              75.0              0.0        0.0                      NaN
# 4              40.0             30.0        0.0                     28.0
#
#   gender_balance
# 0   mostly women
# 1   mostly women
# 2            NaN
# 3       balanced
# 4       balanced

# %%
import os
os.chdir("C:/Users/jacqu/OneDrive/Documents/MSDS/datasets")
whadb = sqlite3.connect("whadb")

# %%
df.to_sql('wha', whadb, index=False, chunksize=1000, if_exists='replace')
# Out:
# 2843

# %%
wha_cursor = whadb.cursor()

# %% [markdown]
# ## Problem 14
# Write `pandas` code that replicates the output of the following SQL code:
# ```
# SELECT size, type, premiums AS insurance, percent_female FROM whpps
# WHERE industry = 'Hospitals' AND premium_change='Smaller'
# ORDER BY percent_female DESC;
# ```
# For each of these queries, your feature names might be different from the ones listed in the query, depending on the names you chose in problem 3.
# [2 points]

# %%
## SQL version
wha_cursor.execute("SELECT Employee_Size, Organization_Type_Profit, Health_Insur_Type AS insurance, Sex_F \
FROM wha \
WHERE Industry = 'Hospital Worksites' AND Personal_Health_Insur='Smaller' \
ORDER BY Sex_F DESC")
cur_df = wha_cursor.fetchall()
pd.DataFrame(cur_df)
# Out:
#          0                   1        2     3
# 0   Medium          non-profit     Full  89.0
# 1    Large          non-profit  Partial  80.0
# 2    Large          non-profit  Partial  80.0
# 3    Small          non-profit     Full  75.0
# 4   Medium          non-profit  Partial  65.0
# 5   Medium  for profit-private     Full  50.0
# 6   Medium                None  Partial   NaN
# 7   Medium          non-profit  Partial   NaN
# 8   Medium          non-profit     Full   NaN
# 9   Medium          non-profit     Full   NaN
# 10   Large          non-profit  Partial   NaN

# %%
## pandas version
df.loc[:,["Employee_Size", "Organization_Type_Profit", "Health_Insur_Type", "Sex_F"]]\
.loc[np.where((df["Industry"] == 'Hospital Worksites') & (df["Personal_Health_Insur"]=='Smaller'))]\
.sort_values("Sex_F", ascending=False)
# Out:
#     Employee_Size Organization_Type_Profit Health_Insur_Type  Sex_F
# 320        Medium               non-profit              Full   89.0
# 187         Large               non-profit           Partial   80.0
# 214         Large               non-profit           Partial   80.0
# 229         Small               non-profit              Full   75.0
# 191        Medium               non-profit           Partial   65.0
# 3          Medium       for profit-private              Full   50.0
# 11         Medium                      NaN           Partial    NaN
# 48         Medium               non-profit           Partial    NaN
# 51         Medium               non-profit              Full    NaN
# 75         Medium               non-profit              Full    NaN
# 97          Large               non-profit           Partial    NaN

# %% [markdown]
# ## Problem 15
# Write `pandas` code that replicates the output of the following SQL code:
# ```
# SELECT industry,
#     AVG(percent_female) as percent_female,
#     AVG(percent_under30) as percent_under30,
#     AVG(percent_over60) as percent_over60
# FROM whpps
# GROUP BY industry
# ORDER BY percent_female DESC;
# ```
# [2 points]

# %%
## SQL version
wha_cursor.execute("SELECT Industry, AVG(Sex_F) AS percent_female, \
AVG(Under_30) AS percent_under30, AVG(Plus_60) AS percent_over60 \
FROM wha \
GROUP BY Industry \
ORDER BY percent_female DESC")
cur_df = wha_cursor.fetchall()
pd.DataFrame(cur_df)
# Out:
#                                   0          1          2          3
# 0                   Public Services  80.657143  25.745665  11.349570
# 1                Hospital Worksites  76.427027  27.213793  16.489655
# 2         Arts and Customer Service  53.804416  38.566343  11.544872
# 3              Business and Finance  50.632184  23.821752  12.465465
# 4                      Public Admin  39.056738  21.015625  15.015385
# 5  Trade, Transportion, Warehousing  32.657258  29.108696  12.584034
# 6        Manual Labor and Resources  20.328605  22.257143  10.690355
# 7                        Unrecorded        NaN        NaN        NaN

# %%
## pandas version
df.loc[:,["Industry", "Sex_F", "Under_30", "Plus_60"]]\
.groupby(by="Industry").mean()\
.sort_values("Sex_F", ascending=False)
# Out:
#                                       Sex_F   Under_30    Plus_60
# Industry
# Public Services                   80.657143  25.745665  11.349570
# Hospital Worksites                76.427027  27.213793  16.489655
# Arts and Customer Service         53.804416  38.566343  11.544872
# Business and Finance              50.632184  23.821752  12.465465
# Public Admin                      39.056738  21.015625  15.015385
# Trade, Transportion, Warehousing  32.657258  29.108696  12.584034
# Manual Labor and Resources        20.328605  22.257143  10.690355
# Unrecorded                              NaN        NaN        NaN

# %% [markdown]
# ## Problem 16
# Write `pandas` code that replicates the output of the following SQL code:
# ```
# SELECT gender_balance, premiums, COUNT(*)
# FROM whpps
# GROUP BY gender_balance, premiums
# HAVING gender_balance is NOT NULL and premiums is NOT NULL;
# ```
# [2 points]

# %%
## SQL version
wha_cursor.execute("SELECT gender_balance, Health_Insur_Type, COUNT(*) \
FROM wha \
GROUP BY gender_balance, Health_Insur_Type \
HAVING gender_balance is NOT NULL and Health_Insur_Type is NOT NULL")
cur_df = wha_cursor.fetchall()
pd.DataFrame(cur_df)
# Out:
#               0        1    2
# 0      balanced     Full  226
# 1      balanced       No   77
# 2      balanced  Partial  271
# 3    mostly men     Full  301
# 4    mostly men       No   91
# 5    mostly men  Partial  332
# 6  mostly women     Full  267
# 7  mostly women       No  107
# 8  mostly women  Partial  333

# %%
## pandas version
df["gender_balance"] = pd.Categorical(df["gender_balance"], ['balanced', 'mostly men', 'mostly women'])

# %%
df.loc[:,["gender_balance", "Health_Insur_Type"]]\
.groupby(by=["gender_balance", "Health_Insur_Type"]).value_counts()
# Out:
# gender_balance  Health_Insur_Type
# balanced        Full                 226
#                 No                    77
#                 Partial              271
# mostly men      Full                 301
#                 No                    91
#                 Partial              332
# mostly women    Full                 267
#                 No                   107
#                 Partial              333
# Name: count, dtype: int64
