# %% [markdown]
# # Lab Assignment 11: Data Visualizations
# ## DS 6001: Practice and Application of Data Science
#
# ### Instructions
# Please answer the following questions as completely as possible using text, code, and the results of code as needed. Format your answers in a Jupyter notebook. To receive full credit, make sure you address every part of the problem, and make sure your document is formatted in a clean and professional way.

# %% [markdown]
# ## Problem 0
# Import the following libraries:

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Problem 1
# Write a short paragraph that provides a critique of the following data visualizations. What's good about each figure, and what's not good? Pay particular attention to how well the figure communicates information to a general audience and tells a complete story. Make specific references to the ideas discussed in the first section of the Module 11 Jupyter notebook.

# %% [markdown]
# ### Part a
# <img src="https://i.reddituploads.com/09d4079fd0bf453586b8524478aac4fd?fit=max&h=1536&w=1536&s=0d63d22eed3d44a41002007990acdf2c" width='500'>
#
# [1 point]

# %% [markdown]
# ### Answer 1.a
#
# Right off the bat, I can see that the numbers don't match up with the bar height. However, it's a really simple graph, so it's easy to understand (assuming if the info was correct). If the numbers were correct, that would also add value to the graph because people can get a sense of the whole. At the same time, maybe adding the number of people that took this survey would be a good idea just because that would give an even better sense about how representative this graph is against the population.

# %% [markdown]
# ### Part b
# <img src="https://www.designyourway.net/diverse/2/wronginfo/59426786926.jpg" width='600'>
#
# [1 point]

# %% [markdown]
# ### Answer 1.b
#
# Everything is nicely labeled and the percentages help. However, the colours are not distinct. And I think a 3D pie chart isn't the move for this. I think a bar chart might be better because there are too many pieces in the pie chart that makes it hard to get a sense of the angles. Especially since the largest piece of the pie is 'other', which isn't very informative. So unless they were trying to convey that 'other' sector has the highest birth rates, it's a no from me. And even if that was the goal, that still doesn't tell us much.

# %% [markdown]
# ### Part c
# <img src="https://i.imgur.com/sTVYOIH.jpg" width='400'>
#
# [1 point]

# %% [markdown]
# ### Answer 1.c
#
# The graph is deceiving and confusing to look at because the y-axis is flipped. Despite the coloring, which I assume was supposed to help?, looking at the graph at a glance will cause misunderstandings. In fact, the coloring is also confusing to look at. It's great that they labeled the important year which provides some context (even just a little).

# %% [markdown]
# ## Problem 2
# For the rest of this lab, we will once again be working with the 2019 General Social Survey.

# %%
# %%capture
gss = pd.read_csv("https://github.com/jkropko/DS-6001/raw/master/localdata/gss2018.csv",
                 encoding='cp1252', na_values=['IAP','IAP,DK,NA,uncodeable', 'NOT SURE',
                                               'DK', 'IAP, DK, NA, uncodeable', '.a', "CAN'T CHOOSE"])

# %% [markdown]
# Here is code that cleans the data and gets it ready to be used for data visualizations:

# %%
mycols = ['id', 'wtss', 'sex', 'educ', 'region', 'age', 'coninc',
          'prestg10', 'mapres10', 'papres10', 'sei10', 'satjob',
          'fechld', 'fefam', 'fepol', 'fepresch', 'meovrwrk'] 
gss_clean = gss[mycols]
gss_clean = gss_clean.rename({'wtss':'weight', 
                              'educ':'education', 
                              'coninc':'income', 
                              'prestg10':'job_prestige',
                              'mapres10':'mother_job_prestige', 
                              'papres10':'father_job_prestige', 
                              'sei10':'socioeconomic_index', 
                              'fechld':'relationship', 
                              'fefam':'male_breadwinner', 
                              'fehire':'hire_women', 
                              'fejobaff':'preference_hire_women', 
                              'fepol':'men_bettersuited', 
                              'fepresch':'child_suffer',
                              'meovrwrk':'men_overwork'},axis=1)
gss_clean.age = gss_clean.age.replace({'89 or older':'89'})
gss_clean.age = gss_clean.age.astype('float')

# %% [markdown]
# The `gss_clean` dataframe now contains the following features:
#
# * `id` - a numeric unique ID for each person who responded to the survey
# * `weight` - survey sample weights
# * `sex` - male or female
# * `education` - years of formal education
# * `region` - region of the country where the respondent lives
# * `age` - age
# * `income` - the respondent's personal annual income
# * `job_prestige` - the respondent's occupational prestige score, as measured by the GSS using the methodology described above
# * `mother_job_prestige` - the respondent's mother's occupational prestige score, as measured by the GSS using the methodology described above
# * `father_job_prestige` -the respondent's father's occupational prestige score, as measured by the GSS using the methodology described above
# * `socioeconomic_index` - an index measuring the respondent's socioeconomic status
# * `satjob` - responses to "On the whole, how satisfied are you with the work you do?"
# * `relationship` - agree or disagree with: "A working mother can establish just as warm and secure a relationship with her children as a mother who does not work."
# * `male_breadwinner` - agree or disagree with: "It is much better for everyone involved if the man is the achiever outside the home and the woman takes care of the home and family."
# * `men_bettersuited` - agree or disagree with: "Most men are better suited emotionally for politics than are most women."
# * `child_suffer` - agree or disagree with: "A preschool child is likely to suffer if his or her mother works."
# * `men_overwork` - agree or disagree with: "Family life often suffers because men concentrate too much on their work."

# %% [markdown]
# ### Part a
# Reorder the categories of `relationship` to "strongly agree", "agree", "disagree", and "strongly disagree".
#
# Then create a simple barplot that shows the frequencies of the categories of `relationship` three times:
# * once using `matplotlib` alone,
# * once using `seaborn`,
# * and once using the `.plot()` method from `pandas`.
#
# Make sure each barplot has descriptive axis labels and a title, and set a good size for each figure displayed in the Jupyter notebook. [2 points]

# %%
gss_clean.relationship.unique()
# Out:
# array(['strongly agree', nan, 'agree', 'disagree', 'strongly disagree'],
#       dtype=object)

# %%
gss_clean.relationship = gss_clean.relationship.astype('category')\
.cat.reorder_categories(["strongly agree",
                         "agree",
                         "disagree",
                         "strongly disagree"])
gss_clean.relationship.unique()
# Out:
# ['strongly agree', NaN, 'agree', 'disagree', 'strongly disagree']
# Categories (4, object): ['strongly agree', 'agree', 'disagree', 'strongly disagree']

# %%
grel_bar = gss_clean.relationship.value_counts().reset_index()
grel_bar
# Out:
#         relationship  count
# 0              agree    670
# 1     strongly agree    480
# 2           disagree    324
# 3  strongly disagree     76

# %%
## matplotlib
plt.figure(figsize=(9,3))
plt.bar(x='relationship', height='count', data=grel_bar)
plt.xlabel("Relationship Cate. Opinion")
plt.ylabel("Frequency")
plt.title("Number of Opinions for Each Relationship Cate.")
plt.show()

# %%
## seaborn
plt.figure(figsize=(9,3))
sns.barplot(x='relationship', y='count', data=grel_bar)
plt.xlabel("Relationship Cate. Opinion")
plt.ylabel("Frequency")
plt.title("Number of Opinions for Each Relationship Cate.")
# Out:
# Text(0.5, 1.0, 'Number of Opinions for Each Relationship Cate.')

# %%
## .plot from pandas
grel_bar.plot(x='relationship', y='count', kind='bar', figsize=(9,3))
plt.xlabel("Relationship Cate. Opinion")
plt.ylabel("Frequency")
plt.title("Number of Opinions for Each Relationship Cate.")
# Out:
# Text(0.5, 1.0, 'Number of Opinions for Each Relationship Cate.')

# %% [markdown]
# ### Part b
# Create two barplots that show
# * the frequency of the different levels of agreement for `relationship` for men and for women on the same plot,
# * with bars for men and bars for women side-by-side,
# * using different colors for the bars for men and the bars for women,
# * listing these colors and the sex they refer to in a legend,
# * and labeling each bar with the number the bar represents.
#
# Create the first barplot using `seaborn` with the bars oriented vertically, and create the second barplot using the `.plot()` method with the bars oriented horizontally. [2 points]

# %%
ggenrel_bar = gss_clean.groupby(['relationship','sex'])\
.size().reset_index().rename({0:"counts"}, axis=1)
ggenrel_bar
# Out:
#         relationship     sex  counts
# 0     strongly agree  female     337
# 1     strongly agree    male     143
# 2              agree  female     344
# 3              agree    male     326
# 4           disagree  female     146
# 5           disagree    male     178
# 6  strongly disagree  female      39
# 7  strongly disagree    male      37

# %%
## seaborn, vertical bars
plt.figure(figsize=(9,3))
sns.barplot(x='relationship', y='counts', hue='sex',
            data=ggenrel_bar)
plt.xlabel("Relationship Opinion")
plt.ylabel("Frequency")
plt.legend(title="Sex")
plt.title("Opinions on Relationship Cate. Based on Gender")
# Out:
# Text(0.5, 1.0, 'Opinions on Relationship Cate. Based on Gender')

# %%
ggenrel_bar = ggenrel_bar.pivot_table(index='relationship', columns='sex', values='counts')

# %%
## .plot pandas, horizontal bars
ggenrel_bar.plot(kind='barh',
                 figsize=(6,4))
plt.ylabel("Relationship Opinion")
plt.xlabel("Frequency")
plt.legend(title="Sex")
plt.title("Opinions on Relationship Cate. Based on Gender")
# Out:
# Text(0.5, 1.0, 'Opinions on Relationship Cate. Based on Gender')

# %% [markdown]
# ### Part c
# Create a visualization with
# * nine barplots, arranged in a 3x3 grid.
# * The barplots should refer to each of the nine categories of `region`,
# * and each barplot should be given a label that contains the name of the region.
# * Within each barplot, list the categories of `relationship`,
# * and display horizontal bars.
#
# Only one figure is required. Use `seaborn`, `matplotlib`, and `.plot()` as you see fit. [2 points]

# %%
gregrel_bar = gss_clean.groupby(['region','relationship']).size().reset_index().rename({0:"counts"}, axis=1)

# %%
gregrel_bar.region.unique()
# Out:
# array(['e. nor. central', 'e. sou. central', 'middle atlantic',
#        'mountain', 'new england', 'pacific', 'south atlantic',
#        'w. nor. central', 'w. sou. central'], dtype=object)

# %%
gregrel_bar.region = gregrel_bar.region.replace(['e. nor. central', 'e. sou. central', 'middle atlantic',
       'mountain', 'new england', 'pacific', 'south atlantic',
       'w. nor. central', 'w. sou. central'],
                                               ["E. North Central", "E. South Central", "Mid-Atlantic", "Mountain",
                                               "New England", "Pacific", "South Atlantic", 
                                                "W. North Central", "W. South Central"])

# %%
grr_fg = sns.FacetGrid(gregrel_bar, col='region', col_wrap=3, hue='region')
grr_fg.map(sns.barplot, 'counts', 'relationship')
grr_fg.set_titles('{col_name}')
grr_fg.set_axis_labels("Counts", "Relationship Opinion Cate.")
# Out:
# C:\Users\jacqu\anaconda3\lib\site-packages\seaborn\axisgrid.py:712: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# C:\Users\jacqu\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## Problem 3
# Write code that exactly replicates the following figures, including all aesthetic choices. **Don't worry, however, about making the size of the figures exactly the same as that varies from browser to browser.** All of the following figures are generated by a primary graphing function from `seaborn`.

# %% [markdown]
# ### Part a
# Replicate the following figure:
# <img src="https://raw.githubusercontent.com/jkropko/DS-6001/master/localimages/parta.png" width='700'>
#
# [Hint: the values of occuptational prestige and socioeconomic status are the means of `job_prestige` and `socioeconomic_index` within years of `education`. Note that values of `education` less than 8 are excluded.] [2 points]

# %%
noless8 = gss_clean.query("education>=8")

# %%
parta = noless8.groupby('education')[['job_prestige','socioeconomic_index']].mean()

# %%
plt.figure(figsize=(9,6))
sns.lineplot(data=parta['job_prestige'], label='Occupational Prestige')
sns.lineplot(data=parta['socioeconomic_index'], label='Socioeconomic Status', linestyle='dashed')
plt.ylim(bottom=0, top=80)  
plt.xlabel("Years of formal education")
plt.ylabel("Value")
plt.title("Occupational Prestige and Socioeconomic Status vs. Years of Education")
plt.legend(title="Index")

# %% [markdown]
# ### Part b
# Replicate the following figure:
# <img src="https://raw.githubusercontent.com/jkropko/DS-6001/master/localimages/partb.png" width='700'>
#
# [Hint: to match the color scheme, you will need to set `center=0`.] [2 points]

# %%
corr_matrix = gss_clean[['job_prestige','father_job_prestige', 
                         'mother_job_prestige', 'income', 'socioeconomic_index']].corr()

# %%
plt.figure(figsize=(15,15))
sns.heatmap(corr_matrix, annot=True, center=0)
plt.title("Correlation Between Personal Economic Indicators")
plt.xticks(rotation=0)
plt.yticks(va='top')
# Out:
# (array([0.5, 1.5, 2.5, 3.5, 4.5]),
#  [Text(0, 0.5, 'job_prestige'),
#   Text(0, 1.5, 'father_job_prestige'),
#   Text(0, 2.5, 'mother_job_prestige'),
#   Text(0, 3.5, 'income'),
#   Text(0, 4.5, 'socioeconomic_index')])

# %% [markdown]
# ### Part c
# Replicate the following figure:
# <img src="https://raw.githubusercontent.com/jkropko/DS-6001/master/localdata/partc2.png" width='600'>
#
# [Hint: The individual plots inside the grid have `height=4` and `aspect=1`, and to include the overall title I used
# ```
# g.fig.subplots_adjust(top=.95)
# g.fig.suptitle('Income vs. Prestige by Education', fontsize=16)
# ```
# You will first need to create a version of `education` that collapses values from 0 to 10 to "10 years or fewer" and collapses values from 17 to 20 to "More than 16 years". You can use `.map()`, `.replace()`, or `pd.cut()` to do that.] [3 points]

# %%
gss_clean['education'] = pd.cut(x=gss_clean.education, bins=[-np.inf, 10, 11, 12, 13, 14, 15, 16, np.inf],
                    labels=['10 years or fewer', '11 years', '12 years',
                            '13 years', '14 years', '15 years', '16 years',
                           'More than 16 years'])

# %%
partc = gss_clean[['education','job_prestige','income']]

# %%
pc_fg = sns.FacetGrid(partc, col='education', col_wrap=2, height=4, aspect=1)
pc_fg.map(sns.scatterplot, 'job_prestige', 'income')
pc_fg.map(sns.regplot, 'job_prestige', 'income', scatter=False)
pc_fg.set_titles('{col_name}')
pc_fg.fig.subplots_adjust(top=0.94)
pc_fg.fig.suptitle('Income vs. Prestige by Education', fontsize=16)
pc_fg.set_axis_labels("Occupational Prestige", "Income")
# Out:
# C:\Users\jacqu\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\jacqu\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## Problem 4
# There is a consistent finding that in the United States that [women get paid only 80% of what men get paid](https://nwlc.org/issue/equal-pay-and-the-wage-gap/). Other research however finds that the gap is much smaller when comparing [men and women who hold the same job](https://www.politifact.com/factchecks/2018/apr/13/tina-smith/do-women-get-only-80-percent-pay-men-do-same-job/). In this problem you will use the GSS data to investigate the following questions:
#
# 1. Do men have higher incomes than women?
#
# 2. If there is a difference, is this difference due to the fact that men have jobs with higher occupational prestige than women?
#
# You may use any kind of data visualization and you may use multiple visualizations to find an answer to these questions. In order to receive credit for this problem, you must write in text what parts of your visualizations are important and what we should learn from the visualizations to answer the questions. Please consider the entire distributions of income and occupational prestige, not just the means or medians. [4 points]

# %%
q4a = gss_clean[['sex','income']].dropna()
q4a_f = q4a.query("sex=='female'")
q4a_m = q4a.query("sex=='male'")

# %%
plt.figure(figsize=(8,4))
sns.kdeplot(x='income', data=q4a_m, fill=True, label='Dist. of Income for Males')
sns.kdeplot(x='income', data=q4a_f, fill=True, label='Dist. of Income for Females')
plt.xlabel("Income Distribution")
plt.legend()
plt.title("Distribution of Income by Gender")
# Out:
# Text(0.5, 1.0, 'Distribution of Income by Gender')

# %%
q4b = gss_clean[['job_prestige','sex','income']]

# %%
q4b_fg = sns.FacetGrid(q4b, col='sex', hue='sex')
q4b_fg.map(sns.scatterplot, 'job_prestige', 'income', alpha=0.5)
q4b_fg.set_titles("{col_name}")
q4b_fg.map(sns.regplot, 'job_prestige', 'income', scatter=False, color='black')
# Out:
# C:\Users\jacqu\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\jacqu\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# 1. Do men have higher incomes than women?
#
# To answer question one, I went with a distribution graph to show if there was a difference in income between the sexes overall. If we look at the distribution for incomes betwen around 50K and a little over 100K, there does seem to be a difference in distribution. In this income range, it seems as though there are more males within this income range rather than females (based on the participants in the survey).
#
# In addition, below 50K, there seems to be a higher distribution of females within the lower income range. This is a good indication that males do have higher incomes than females.
#
# 2. If there is a difference, is this difference due to the fact that men have jobs with higher occupational prestige than women?
#
# To answer this second question, I created a scatterplot between the two genders with their job prestige and income. In this case, the difference doesn't seem to be too noticeable. If you stare at the regression line hard enough, you might see that the regression line for males is a little steeper than the regression line for females. This may indicate that the income for females may be slightly lower, especially in the mid-prestigeous jobs, than males. A more statistical analysis would have to be done to test the significance of this difference.
