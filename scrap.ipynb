# %%
import pandas as pd

# %%
data_path = "C:/Users/jacqu/OneDrive/Documents/MSDS-at-UVA-2023/Projects/Data_Sys/data_sys_data"

# %%
all_beau = pd.read_json(f"{data_path}/All_Beauty_5.json", lines=True)
all_neg = pd.read_json(f"{data_path}/Varied_Negative_Reviews.json", lines=True)
all_app = pd.read_json(f"{data_path}/Appliances_5.json", lines=True)

# %%
all_beau.head(2)
# Out:
#    overall  verified   reviewTime      reviewerID        asin  \
# 0        5      True   09 1, 2016  A3CIUOJXQ5VDQ2  B0000530HU
# 1        5      True  11 14, 2013  A3H7T87S984REU  B0000530HU
#
#                                                style  reviewerName  \
# 0  {'Size:': ' 7.0 oz', 'Flavor:': ' Classic Ice ...      Shelly F
# 1  {'Size:': ' 7.0 oz', 'Flavor:': ' Classic Ice ...  houserules18
#
#                                           reviewText            summary  \
# 0                   As advertised. Reasonably priced         Five Stars
# 1  Like the oder and the feel when I put it on my...  Good for the face
#
#    unixReviewTime vote image
# 0      1472688000  NaN   NaN
# 1      1384387200  NaN   NaN

# %%
all_neg.head(2)
# Out:
#    overall  verified   reviewTime      reviewerID        asin  \
# 0        1      True   09 1, 2016  A3CIUOJXQ5VDQ2  B0000530HU
# 1        1      True  11 14, 2013  A3H7T87S984REU  B0000530HU
#
#                                                style  reviewerName  \
# 0  {'Size:': ' 7.0 oz', 'Flavor:': ' Classic Ice ...      Shelly F
# 1  {'Size:': ' 7.0 oz', 'Flavor:': ' Classic Ice ...  houserules18
#
#                                           reviewText              summary  \
# 0  Very unsatisfied with this purchase. It's noth...   Very disappointing
# 1  This product was incredibly disappointing and ...  Would not recommend
#
#    unixReviewTime vote image
# 0      1472688000  NaN   NaN
# 1      1384387200  NaN   NaN

# %%
all_app.head(2)
# Out:
#    overall  verified   reviewTime      reviewerID        asin  \
# 0        5      True  08 22, 2013  A34A1UP40713F8  B00009W3I4
# 1        5      True   02 8, 2016  A1AHW6I678O6F2  B00009W3PA
#
#                        style   reviewerName  \
# 0  {'Style:': ' Dryer Vent'}  James. Backus
# 1       {'Size:': ' 6-Foot'}         kevin.
#
#                                           reviewText        summary  \
# 0  I like this as a vent as well as something tha...  Great product
# 1                                          good item     Five Stars
#
#    unixReviewTime vote image
# 0      1377129600  NaN   NaN
# 1      1454889600  NaN   NaN

# %%
pd.concat([all_beau, all_neg, all_app], axis=0).sh
# Out:
#    overall  verified   reviewTime      reviewerID        asin  \
# 0        5      True   09 1, 2016  A3CIUOJXQ5VDQ2  B0000530HU
# 1        5      True  11 14, 2013  A3H7T87S984REU  B0000530HU
#
#                                                style  reviewerName  \
# 0  {'Size:': ' 7.0 oz', 'Flavor:': ' Classic Ice ...      Shelly F
# 1  {'Size:': ' 7.0 oz', 'Flavor:': ' Classic Ice ...  houserules18
#
#                                           reviewText            summary  \
# 0                   As advertised. Reasonably priced         Five Stars
# 1  Like the oder and the feel when I put it on my...  Good for the face
#
#    unixReviewTime vote image
# 0      1472688000  NaN   NaN
# 1      1384387200  NaN   NaN
