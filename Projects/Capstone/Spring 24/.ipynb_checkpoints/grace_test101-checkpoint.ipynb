# %%
default_path = "C:/Users/jacqu/Downloads/"
source_path = default_path+"trials/101_cases_pdf"
destination_path = default_path+"trials/101_cases_txt"

# %%
import sys
sys.path.append("C:/Users/jacqu/OneDrive/Documents/MSDS-at-UVA-2023/Projects/Capstone/Spring 24") 
from extraction_run import Extraction

# %%
mydf = Extraction(source_path, destination_path)

# %% [raw]
# mydf.process_pdfs()

# %%
INFO = mydf.create_info()

# %%
mydf.INFO.shape
# Out:
#                                                                                          pdf_path  \
# file_title
# A.B. v. Shilo Inn, Salem, LLC, 2023 U.S. Dist. ...  C:/Users/jacqu/Downloads/trials/101_cases_pdf
# A.D. v. Best Western Int_l, Inc., 2023 U.S. Dis...  C:/Users/jacqu/Downloads/trials/101_cases_pdf
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...  C:/Users/jacqu/Downloads/trials/101_cases_pdf
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...  C:/Users/jacqu/Downloads/trials/101_cases_pdf
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...  C:/Users/jacqu/Downloads/trials/101_cases_pdf
# ...                                                                                           ...
# Vidal v. Galaxy 2439 Enters., LLC, 2023 U.S. Di...  C:/Users/jacqu/Downloads/trials/101_cases_pdf
# Williams v. Sisolak, 2023 U.S. App. LEXIS 32338     C:/Users/jacqu/Downloads/trials/101_cases_pdf
# Wilson v. Conn. DOT, 2023 U.S. Dist. LEXIS 217795   C:/Users/jacqu/Downloads/trials/101_cases_pdf
# Wisdom v. Perez, 2023 U.S. Dist. LEXIS 217366       C:/Users/jacqu/Downloads/trials/101_cases_pdf
# Woodhull Freedom Found. v. United States, 72 F....  C:/Users/jacqu/Downloads/trials/101_cases_pdf
#
#                                                                                          txt_path  \
# file_title
# A.B. v. Shilo Inn, Salem, LLC, 2023 U.S. Dist. ...  C:/Users/jacqu/Downloads/trials/101_cases_txt
# A.D. v. Best Western Int_l, Inc., 2023 U.S. Dis...  C:/Users/jacqu/Downloads/trials/101_cases_txt
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...  C:/Users/jacqu/Downloads/trials/101_cases_txt
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...  C:/Users/jacqu/Downloads/trials/101_cases_txt
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...  C:/Users/jacqu/Downloads/trials/101_cases_txt
# ...                                                                                           ...
# Vidal v. Galaxy 2439 Enters., LLC, 2023 U.S. Di...  C:/Users/jacqu/Downloads/trials/101_cases_txt
# Williams v. Sisolak, 2023 U.S. App. LEXIS 32338     C:/Users/jacqu/Downloads/trials/101_cases_txt
# Wilson v. Conn. DOT, 2023 U.S. Dist. LEXIS 217795   C:/Users/jacqu/Downloads/trials/101_cases_txt
# Wisdom v. Perez, 2023 U.S. Dist. LEXIS 217366       C:/Users/jacqu/Downloads/trials/101_cases_txt
# Woodhull Freedom Found. v. United States, 72 F....  C:/Users/jacqu/Downloads/trials/101_cases_txt
#
#                                                                                             narrative
# file_title
# A.B. v. Shilo Inn, Salem, LLC, 2023 U.S. Dist. ...  OPINION AND ORDER GRANTING DEFENDANT  SUMMIT H...
# A.D. v. Best Western Int_l, Inc., 2023 U.S. Dis...  OPINION AND ORDER This matter comes before the...
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...  OPINION AND ORDER This matter comes before the...
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...  OPINION AND ORDER This matter comes before the...
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...  OPINION AND ORDER This matter comes before the...
# ...                                                                                               ...
# Vidal v. Galaxy 2439 Enters., LLC, 2023 U.S. Di...  MEMORANDUM OPINION SHIPP, District Judge This ...
# Williams v. Sisolak, 2023 U.S. App. LEXIS 32338     [*1] U.S. COURT OF APPEALS Appeal from the Uni...
# Wilson v. Conn. DOT, 2023 U.S. Dist. LEXIS 217795   [*1] RULING  ON  DEFENDANT'S  MOTION  TO  DISM...
# Wisdom v. Perez, 2023 U.S. Dist. LEXIS 217366       MEMORANDUM & ORDER KIYO A. MATSUMOTO, United S...
# Woodhull Freedom Found. v. United States, 72 F....  [*1292]  M, Circuit Judge: In 2018, Congress  ...
#
# [102 rows x 3 columns]

# %%
index_list_df1 = INFO.index

# %%
import pandas as pd
import numpy as np

# %%
labels = pd.read_csv(default_path+"trials/updated_101_cases.csv")
labels.shape
# Out:
#                                               CaseName  Sex_Trafficking
# 0    A.B. v. Shilo Inn, Salem, LLC, 2023 U.S. Dist....                1
# 1    A.D. v. Best Western Int_l, Inc., 2023 U.S. Di...                1
# 2    A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. D...                1
# 3    A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. D...                1
# 4    A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. D...                1
# ..                                                 ...              ...
# 96   Vidal v. Galaxy 2439 Enters., LLC, 2023 U.S. D...                0
# 97   Williams v. Sisolak, 2023 U.S. App. LEXIS 3233...                1
# 98   Wilson v. Conn. DOT, 2023 U.S. Dist. LEXIS 217...                0
# 99   Wisdom v. Perez, 2023 U.S. Dist. LEXIS 217366.pdf                0
# 100  Woodhull Freedom Found. v. United States, 72 F...                1
#
# [101 rows x 2 columns]

# %%
labels.set_index('CaseName', inplace=True)

# %%
index_list_df2 = labels.index

# %%
#labels.drop(columns=['Narrative'], inplace=True)
labels.index = [each_title.split(".pdf")[0].strip() for each_title in labels.index]
labels.index.name = 'file_title'
labels.rename(columns={"Sex_Trafficking":"label"}, inplace=True)
labels
# Out:
#                                                     label
# file_title
# A.B. v. Shilo Inn, Salem, LLC, 2023 U.S. Dist. ...      1
# A.D. v. Best Western Int_l, Inc., 2023 U.S. Dis...      1
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...      1
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...      1
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...      1
# ...                                                   ...
# Vidal v. Galaxy 2439 Enters., LLC, 2023 U.S. Di...      0
# Williams v. Sisolak, 2023 U.S. App. LEXIS 32338         1
# Wilson v. Conn. DOT, 2023 U.S. Dist. LEXIS 217795       0
# Wisdom v. Perez, 2023 U.S. Dist. LEXIS 217366           0
# Woodhull Freedom Found. v. United States, 72 F....      1
#
# [101 rows x 1 columns]

# %%
INFO = mydf.add_labels(labels)
INFO.shape
# Out:
#                                                                                          pdf_path  \
# file_title
# A.B. v. Shilo Inn, Salem, LLC, 2023 U.S. Dist. ...  C:/Users/jacqu/Downloads/trials/101_cases_pdf
# A.D. v. Best Western Int_l, Inc., 2023 U.S. Dis...  C:/Users/jacqu/Downloads/trials/101_cases_pdf
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...  C:/Users/jacqu/Downloads/trials/101_cases_pdf
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...  C:/Users/jacqu/Downloads/trials/101_cases_pdf
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...  C:/Users/jacqu/Downloads/trials/101_cases_pdf
# ...                                                                                           ...
# J.M. v. Choice Hotels Int'l, Inc., 2023 U.S. Di...                                            NaN
# People v. Lamb_ 37 N.Y.3d 1174.PDF                                                            NaN
# S.Y. v. Wyndham Hotels(2)                                                                     NaN
# S.Y. v. Wyndham Hotels(3)                                                                     NaN
# Samsung Fire _ Marine Ins. Co., Ltd. v. UFVS Mg...                                            NaN
#
#                                                                                          txt_path  \
# file_title
# A.B. v. Shilo Inn, Salem, LLC, 2023 U.S. Dist. ...  C:/Users/jacqu/Downloads/trials/101_cases_txt
# A.D. v. Best Western Int_l, Inc., 2023 U.S. Dis...  C:/Users/jacqu/Downloads/trials/101_cases_txt
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...  C:/Users/jacqu/Downloads/trials/101_cases_txt
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...  C:/Users/jacqu/Downloads/trials/101_cases_txt
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...  C:/Users/jacqu/Downloads/trials/101_cases_txt
# ...                                                                                           ...
# J.M. v. Choice Hotels Int'l, Inc., 2023 U.S. Di...                                            NaN
# People v. Lamb_ 37 N.Y.3d 1174.PDF                                                            NaN
# S.Y. v. Wyndham Hotels(2)                                                                     NaN
# S.Y. v. Wyndham Hotels(3)                                                                     NaN
# Samsung Fire _ Marine Ins. Co., Ltd. v. UFVS Mg...                                            NaN
#
#                                                                                             narrative  \
# file_title
# A.B. v. Shilo Inn, Salem, LLC, 2023 U.S. Dist. ...  OPINION AND ORDER GRANTING DEFENDANT  SUMMIT H...
# A.D. v. Best Western Int_l, Inc., 2023 U.S. Dis...  OPINION AND ORDER This matter comes before the...
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...  OPINION AND ORDER This matter comes before the...
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...  OPINION AND ORDER This matter comes before the...
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...  OPINION AND ORDER This matter comes before the...
# ...                                                                                               ...
# J.M. v. Choice Hotels Int'l, Inc., 2023 U.S. Di...                                                NaN
# People v. Lamb_ 37 N.Y.3d 1174.PDF                                                                NaN
# S.Y. v. Wyndham Hotels(2)                                                                         NaN
# S.Y. v. Wyndham Hotels(3)                                                                         NaN
# Samsung Fire _ Marine Ins. Co., Ltd. v. UFVS Mg...                                                NaN
#
#                                                     label
# file_title
# A.B. v. Shilo Inn, Salem, LLC, 2023 U.S. Dist. ...    1.0
# A.D. v. Best Western Int_l, Inc., 2023 U.S. Dis...    1.0
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...    1.0
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...    1.0
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...    1.0
# ...                                                   ...
# J.M. v. Choice Hotels Int'l, Inc., 2023 U.S. Di...    1.0
# People v. Lamb_ 37 N.Y.3d 1174.PDF                    1.0
# S.Y. v. Wyndham Hotels(2)                             1.0
# S.Y. v. Wyndham Hotels(3)                             1.0
# Samsung Fire _ Marine Ins. Co., Ltd. v. UFVS Mg...    1.0
#
# [109 rows x 4 columns]

# %% [raw]
# INFO[INFO.narrative.isna()]

# %% [raw]
# INFO[INFO.label.isna()]
