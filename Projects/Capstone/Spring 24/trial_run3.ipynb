# %%
default_path = "C:/Users/jacqu/Downloads/"
## doesn't exist technically...
source_path = default_path+"trials/99_cases_pdf"
destination_path = default_path+"trials/99_cases_txt"

# %%
import sys
sys.path.append("C:/Users/jacqu/OneDrive/Documents/MSDS-at-UVA-2023/Projects/Capstone/Spring 24") 
from extraction_run import Extraction

# %%
mydf = Extraction(source_path, destination_path)

# %%
mydf.create_info()
# Out:
#                                                                                         pdf_path  \
# file_title
# A.B. v. Shilo Inn, Salem, LLC, 2023 U.S. Dist. ...  C:/Users/jacqu/Downloads/trials/99_cases_pdf
# A.D. v. Best Western Int_l, Inc., 2023 U.S. Dis...  C:/Users/jacqu/Downloads/trials/99_cases_pdf
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...  C:/Users/jacqu/Downloads/trials/99_cases_pdf
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...  C:/Users/jacqu/Downloads/trials/99_cases_pdf
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...  C:/Users/jacqu/Downloads/trials/99_cases_pdf
# ...                                                                                          ...
# Vidal v. Galaxy 2439 Enters., LLC, 2023 U.S. Di...  C:/Users/jacqu/Downloads/trials/99_cases_pdf
# Williams v. Sisolak, 2023 U.S. App. LEXIS 32338     C:/Users/jacqu/Downloads/trials/99_cases_pdf
# Wilson v. Conn. DOT, 2023 U.S. Dist. LEXIS 217795   C:/Users/jacqu/Downloads/trials/99_cases_pdf
# Wisdom v. Perez, 2023 U.S. Dist. LEXIS 217366       C:/Users/jacqu/Downloads/trials/99_cases_pdf
# Woodhull Freedom Found. v. United States, 72 F....  C:/Users/jacqu/Downloads/trials/99_cases_pdf
#
#                                                                                         txt_path
# file_title
# A.B. v. Shilo Inn, Salem, LLC, 2023 U.S. Dist. ...  C:/Users/jacqu/Downloads/trials/99_cases_txt
# A.D. v. Best Western Int_l, Inc., 2023 U.S. Dis...  C:/Users/jacqu/Downloads/trials/99_cases_txt
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...  C:/Users/jacqu/Downloads/trials/99_cases_txt
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...  C:/Users/jacqu/Downloads/trials/99_cases_txt
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...  C:/Users/jacqu/Downloads/trials/99_cases_txt
# ...                                                                                          ...
# Vidal v. Galaxy 2439 Enters., LLC, 2023 U.S. Di...  C:/Users/jacqu/Downloads/trials/99_cases_txt
# Williams v. Sisolak, 2023 U.S. App. LEXIS 32338     C:/Users/jacqu/Downloads/trials/99_cases_txt
# Wilson v. Conn. DOT, 2023 U.S. Dist. LEXIS 217795   C:/Users/jacqu/Downloads/trials/99_cases_txt
# Wisdom v. Perez, 2023 U.S. Dist. LEXIS 217366       C:/Users/jacqu/Downloads/trials/99_cases_txt
# Woodhull Freedom Found. v. United States, 72 F....  C:/Users/jacqu/Downloads/trials/99_cases_txt
#
# [102 rows x 2 columns]

# %%
import pandas as pd
import numpy as np

# %%
labels = pd.read_csv(default_path+"trials/99_Cases.csv")
labels.set_index('CaseName', inplace=True)
labels.drop(columns=['Narrative'], inplace=True)
labels.index = [each_title.split(".pdf")[0].strip() for each_title in labels.index]
labels.index.name = 'file_title'
labels.rename(columns={"Sex_Trafficking":"label"}, inplace=True)
labels.head()
# Out:
#                                                     label
# file_title
# A.B. v. Shilo Inn, Salem, LLC, 2023 U.S. Dist. ...      1
# A.D. v. Best Western Int_l, Inc., 2023 U.S. Dis...      1
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...      1
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...      1
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...      1

# %%
INFO = mydf.add_labels(labels)
INFO.head()
# Out:
#                                                                                         pdf_path  \
# file_title
# A.B. v. Shilo Inn, Salem, LLC, 2023 U.S. Dist. ...  C:/Users/jacqu/Downloads/trials/99_cases_pdf
# A.D. v. Best Western Int_l, Inc., 2023 U.S. Dis...  C:/Users/jacqu/Downloads/trials/99_cases_pdf
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...  C:/Users/jacqu/Downloads/trials/99_cases_pdf
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...  C:/Users/jacqu/Downloads/trials/99_cases_pdf
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...  C:/Users/jacqu/Downloads/trials/99_cases_pdf
#
#                                                                                         txt_path  \
# file_title
# A.B. v. Shilo Inn, Salem, LLC, 2023 U.S. Dist. ...  C:/Users/jacqu/Downloads/trials/99_cases_txt
# A.D. v. Best Western Int_l, Inc., 2023 U.S. Dis...  C:/Users/jacqu/Downloads/trials/99_cases_txt
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...  C:/Users/jacqu/Downloads/trials/99_cases_txt
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...  C:/Users/jacqu/Downloads/trials/99_cases_txt
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...  C:/Users/jacqu/Downloads/trials/99_cases_txt
#
#                                                     label
# file_title
# A.B. v. Shilo Inn, Salem, LLC, 2023 U.S. Dist. ...      1
# A.D. v. Best Western Int_l, Inc., 2023 U.S. Dis...      1
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...      1
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...      1
# A.D. v. Choice Hotels Int_l, Inc., 2023 U.S. Di...      1

# %%
from model_run import Model

# %%
mymodel = Model(INFO, overwrite=True)

# %%
mymodel.make_corpus()
# Out:
#                                                                        token_str  \
# title                                              sent_num token_num
# A.B. v. Shilo Inn, Salem, LLC, 2023 U.S. Dist. ... 0        0               [*1]
#                                                             1          JUDGMENT:
#                                                             2           AFFIRMED
#                                                             3                 IN
#                                                             4              PART,
# ...                                                                          ...
# Woodhull Freedom Found. v. United States, 72 F.... 601      16         surviving
#                                                             17              this
#                                                             18            Motion
#                                                             19                to
#                                                             20          Dismiss.
#
#                                                                         term_str  \
# title                                              sent_num token_num
# A.B. v. Shilo Inn, Salem, LLC, 2023 U.S. Dist. ... 0        0               [*1]
#                                                             1          judgment:
#                                                             2           affirmed
#                                                             3                 in
#                                                             4              part,
# ...                                                                          ...
# Woodhull Freedom Found. v. United States, 72 F.... 601      16         surviving
#                                                             17              this
#                                                             18            motion
#                                                             19                to
#                                                             20          dismiss.
#
#                                                                       pos_tag
# title                                              sent_num token_num
# A.B. v. Shilo Inn, Salem, LLC, 2023 U.S. Dist. ... 0        0              JJ
#                                                             1             NNP
#                                                             2             NNP
#                                                             3             NNP
#                                                             4             NNP
# ...                                                                       ...
# Woodhull Freedom Found. v. United States, 72 F.... 601      16            VBG
#                                                             17             DT
#                                                             18             NN
#                                                             19             TO
#                                                             20             VB
#
# [858695 rows x 3 columns]
